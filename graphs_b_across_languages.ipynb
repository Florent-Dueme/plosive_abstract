# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from graphs import *
import numpy as np

# %%
data = pd.read_csv(r'all_data_burst_24_01_2022.csv', sep=";")
data["Plosion_index"] = np.log2(data["Plosion_index"])

b_data = data[data.Grapheme == "b"]
v_data = data[data.Grapheme == "v"]

# %%
# graph_sound_group(b_data, lim_y=[2, 5], save=True)

# %%
box_PI(b_data, save=True)
