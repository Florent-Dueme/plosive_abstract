# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from graphs import *

# %%
data = pd.read_csv(r'C:\Users\Dell\Documents\Scripts\Jupyter_notebooks\Experiments\Frspbil\Plosives\Table_data\clean_PI_burst_23_01_2022.csv', sep=";")

data_mono = data[data.Group == "Monolinguals"]
data_bi = data[data.Group == "Bilinguals"]
data_bi_burst = data_bi[data_bi.Burst == True]
data_mono_burst = data_mono[data_mono.Burst == True]
data_bi_b = data_bi[data_bi.Grapheme == "b"]
data_bi_v = data_bi[data_bi.Grapheme == "v"]
data_mono_b = data_mono[data_mono.Grapheme == "b"]
data_mono_v = data_mono[data_mono.Grapheme == "v"]

# %%
data_bi_burst
# Out:
#      Language       Group  Speaker Grapheme     Task                    File  \
# 2238  Spanish  Bilinguals       12        b   naming  b_pic_nam_12_barriga_1
# 2239  Spanish  Bilinguals       12        b   naming   b_pic_nam_12_barrio_1
# 2240  Spanish  Bilinguals       12        b   naming   b_pic_nam_12_basura_1
# 2241  Spanish  Bilinguals       12        b   naming     b_pic_nam_12_bata_1
# 2242  Spanish  Bilinguals       12        b   naming    b_pic_nam_12_beber_1
# ...       ...         ...      ...      ...      ...                     ...
# 4707  Spanish  Bilinguals        9        v  reading  b_reading_9_vivienda_1
# 4708  Spanish  Bilinguals        9        v  reading     b_reading_9_voceo_1
# 4709  Spanish  Bilinguals        9        v  reading     b_reading_9_voces_1
# 4710  Spanish  Bilinguals        9        v  reading   b_reading_9_volante_1
# 4711  Spanish  Bilinguals        9        v  reading  b_reading_9_volverse_1
#
#           Word  Plosion index       VOT    Length Gender  Burst  Error
# 2238   barriga       4.718975  0.064918  0.077842      F   True    NaN
# 2239    barrio       8.142015  0.070904  0.078720      F   True    NaN
# 2240    basura       5.195849  0.067351  0.075306      F   True    NaN
# 2241      bata      12.419969  0.126825  0.131814      F   True    NaN
# 2242     beber      14.648412  0.061497  0.066485      F   True    NaN
# ...        ...            ...       ...       ...    ...    ...    ...
# 4707  vivienda       6.717718  0.059955  0.064943      F   True    NaN
# 4708     voceo       8.755124  0.047326  0.052604      F   True    NaN
# 4709     voces       6.583342  0.057075  0.062063      F   True    NaN
# 4710   volante       4.468694  0.059109  0.063884      F   True    NaN
# 4711  volverse       4.718191  0.058481  0.063469      F   True    NaN
#
# [2307 rows x 13 columns]

# %%
graph_plosives(data_bi_burst)

# %%
data_bi_b.Burst.value_counts()
# Out:
# True     1173
# False      65
# Name: Burst, dtype: int64
