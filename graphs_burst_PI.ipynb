# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from graphs import *
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\Dell\Documents\Scripts\Jupyter_notebooks\Experiments\Frspbil\Plosives\Table_data\clean_PI_burst_23_01_2022.csv', sep=";")

data_mono = data[data.Group == "Monolinguals"]
data_bi = data[data.Group == "Bilinguals"]
data_bi_burst = data_bi[data_bi.Burst == True]
data_mono_burst = data_mono[data_mono.Burst == True]
data_bi_b = data_bi[data_bi.Grapheme == "b"]
data_bi_v = data_bi[data_bi.Grapheme == "v"]
data_mono_b = data_mono[data_mono.Grapheme == "b"]
data_mono_v = data_mono[data_mono.Grapheme == "v"]
data_burst = data[data.Burst == True]

# %%
data_burst
# Out:
#      Language         Group  Speaker Grapheme     Task  \
# 0     Spanish  Monolinguals      101        b   naming
# 2     Spanish  Monolinguals      101        b   naming
# 3     Spanish  Monolinguals      101        b   naming
# 4     Spanish  Monolinguals      101        b   naming
# 5     Spanish  Monolinguals      101        b   naming
# ...       ...           ...      ...      ...      ...
# 4707  Spanish    Bilinguals        9        v  reading
# 4708  Spanish    Bilinguals        9        v  reading
# 4709  Spanish    Bilinguals        9        v  reading
# 4710  Spanish    Bilinguals        9        v  reading
# 4711  Spanish    Bilinguals        9        v  reading
#
#                          File      Word  Plosion index       VOT    Length  \
# 0       b_pic_nam_101_baile_1     baile       6.958387  0.065170  0.070159
# 2     b_pic_nam_101_barriga_1   barriga      11.897856  0.016449  0.023127
# 3      b_pic_nam_101_barrio_1    barrio      12.517455  0.035134  0.044726
# ...

# %%
graph_plosives(data_bi_burst)

# %%
data_bi_b.Burst.value_counts()
# Out:
# True     1173
# False      65
# Name: Burst, dtype: int64

# %%
data_burst["Plosion index"] = np.log2(data_burst["Plosion index"])
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14084/1341156977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_burst["Plosion index"] = np.log2(data_burst["Plosion index"])

# %%
data_burst
# Out:
#      Language         Group  Speaker Grapheme     Task  \
# 0     Spanish  Monolinguals      101        b   naming
# 2     Spanish  Monolinguals      101        b   naming
# 3     Spanish  Monolinguals      101        b   naming
# 4     Spanish  Monolinguals      101        b   naming
# 5     Spanish  Monolinguals      101        b   naming
# ...       ...           ...      ...      ...      ...
# 4707  Spanish    Bilinguals        9        v  reading
# 4708  Spanish    Bilinguals        9        v  reading
# 4709  Spanish    Bilinguals        9        v  reading
# 4710  Spanish    Bilinguals        9        v  reading
# 4711  Spanish    Bilinguals        9        v  reading
#
#                          File      Word  Plosion index       VOT    Length  \
# 0       b_pic_nam_101_baile_1     baile       2.798753  0.065170  0.070159
# 2     b_pic_nam_101_barriga_1   barriga       3.572630  0.016449  0.023127
# 3      b_pic_nam_101_barrio_1    barrio       3.645869  0.035134  0.044726
# ...

# %%
violin_plosives(data_burst, save=True)
